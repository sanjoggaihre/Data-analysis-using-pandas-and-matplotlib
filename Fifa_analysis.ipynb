# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv("fifa_dataset.csv")

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.shape
# Out:
# (18207, 89)

# %%
for i in fifa.columns:
    print(i)
# Out:
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
plt.figure(figsize=[7,5])
plt.bar(list(fifa['Name'].value_counts().keys()[0:5]),list(fifa['Name'].value_counts()[0:5]),color=['orange','red','blue'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=[7,5])
plt.bar(list(fifa['Name'][0:5]),list(fifa['Penalties'][0:5]))
plt.title("Bar diagram for player with penalties")
plt.xlabel("Player")
plt.ylabel("Penalties")
plt.show()

# %%
fifa['Penalties']
# Out:
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64

# %%
fifa['wage_eur']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wage_eur'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pos=fifa[['Name','Position','Nationality','Penalties']]

# %%
pos.head()
# Out:
#                 Name Position Nationality  Penalties
# 0           L. Messi       RF   Argentina       75.0
# 1  Cristiano Ronaldo       ST    Portugal       85.0
# 2          Neymar Jr       LW      Brazil       81.0
# 3             De Gea       GK       Spain       40.0
# 4       K. De Bruyne      RCM     Belgium       79.0

# %%
highpenalties=pos.sort_values(by=['Penalties'],ascending=False)

# %%
highpenalties.head()
# Out:
#              Name Position Nationality  Penalties
# 206  M. Balotelli       LS       Italy       92.0
# 118       Fabinho      CDM      Brazil       91.0
# 16        H. Kane       ST     England       90.0
# 297      M. Kruse       ST     Germany       90.0
# 945     L. Baines       LB     England       90.0

# %%
ger_player=fifa[fifa['Nationality']=='Germany']

# %%
ger_player.shape
# Out:
# (1198, 89)

# %%
ger_player.head(20)
# Out:
#      Unnamed: 0      ID           Name  Age  \
# 11           11  182521       T. Kroos   28
# 18           18  192448  M. ter Stegen   26
# 22           22  167495       M. Neuer   32
# 34           34  178603     M. Hummels   29
# 55           55  222492        L. Sané   22
# 66           66  189596      T. Müller   28
# 68           68  188350        M. Reus   29
# 74           74  176635        M. Özil   29
# 82           82  212622     J. Kimmich   23
# 95           95  183907     J. Boateng   29
# 99           99  179846     S. Khedira   31
# 115         115  212190        N. Süle   22
# 131         131  192563        B. Leno   26
# 136         136  186942    I. Gündoğan   27
# 165         165  213331         J. Tah   22
# 167         167  212188      T. Werner   22
# 169         169  209658    L. Goretzka   23
# 179         179  206113      S. Gnabry   22
# 184         184  202166     J. Draxler   24
# 189         189  200316        T. Horn   25
#
# ...

# %%
ger_player.sort_values(by='Release Clause',ascending=False)[['Name','Position','Release Clause']].head(10)
# Out:
#                  Name Position Release Clause
# 4779        D. Geiger       CM            €9M
# 2450      F. Bastians      LCB            €9M
# 11695  E. Oelschlägel       GK          €998K
# 7755          A. Jung       LB          €997K
# 10318         P. Sohm       LS          €991K
# 10065    F. Viteritti      LCM          €991K
# 11572       T. Müller       GK          €990K
# 11535        S. Bösel      RDM          €990K
# 14670   E. Majetschak       CM          €988K
# 14934      R. Ziegele       CB          €988K

# %%
real_madrid=fifa[fifa['Club']=='Real Madrid']

# %%
real_madrid.shape
# Out:
# (33, 89)

# %%
real_madrid
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 6               6  177003        L. Modrić   32
# 8               8  155862     Sergio Ramos   32
# 11             11  182521         T. Kroos   28
# 19             19  192119      T. Courtois   26
# 27             27  200145         Casemiro   26
# 30             30  197781             Isco   26
# 35             35  176676          Marcelo   30
# 36             36  173731          G. Bale   28
# 46             46  193041         K. Navas   31
# 62             62  201535        R. Varane   25
# 79             79  220834    Marco Asensio   22
# 105           105  165153       K. Benzema   30
# 123           123  204963         Carvajal   26
# 172           172  208618    Lucas Vázquez   27
# 188           188  200724  Nacho Fernández   28
# 328           328  222509    Dani Ceballos   21
# 417           417  234035        Odriozola   22
# 430           430  221639          Mariano   24
# ...

# %%
real_madrid.sort_values(by=['Overall'],ascending=False)[['Name','Nationality','Overall','Potential','Release Clause']].head()
# Out:
#             Name Nationality  Overall  Potential Release Clause
# 6      L. Modrić     Croatia       91         91        €137.4M
# 8   Sergio Ramos       Spain       91         91        €104.6M
# 11      T. Kroos     Germany       90         90        €156.8M
# 19   T. Courtois     Belgium       89         90        €113.7M
# 27      Casemiro      Brazil       88         90        €126.4M

# %%
real_madrid['Nationality'].value_counts()
# Out:
# Spain                 19
# Brazil                 3
# France                 3
# Croatia                1
# Germany                1
# Belgium                1
# Wales                  1
# Costa Rica             1
# Dominican Republic     1
# Uruguay                1
# Argentina              1
# Name: Nationality, dtype: int64

# %%
real_madrid.describe()
# Out:
#          Unnamed: 0             ID        Age    Overall  Potential  \
# count     33.000000      33.000000  33.000000  33.000000  33.000000
# mean    3436.484848  213881.000000  24.030303  78.242424  84.636364
# std     4910.416448   27788.084954   4.537929   9.902747   5.699880
# min        6.000000  155862.000000  17.000000  62.000000  71.000000
# 25%       46.000000  193041.000000  20.000000  67.000000  80.000000
# 50%      417.000000  221639.000000  23.000000  80.000000  86.000000
# 75%     8732.000000  240311.000000  28.000000  87.000000  90.000000
# max    13687.000000  246608.000000  32.000000  91.000000  92.000000
#
#            Special  International Reputation  Weak Foot  Skill Moves  \
# count    33.000000                 33.000000  33.000000    33.000000
# mean   1818.939394                  2.090909   3.212121     2.848485
# std     332.760888                  1.259058   0.649883     1.093195
# min     944.000000                  1.000000   2.000000     1.000000
# ...

# %%
real_madrid.shape
# Out:
# (33, 89)

# %%
real_madrid.mean('Release Clause')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 'Release Clause'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9808/3180929688.py in <module>
# ----> 1 real_madrid.mean('Release Clause')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
# ...

# %%
real_madrid.values
# Out:
# array([[6, 177003, 'L. Modrić', ..., 14.0, 9.0, '€137.4M'],
#        [8, 155862, 'Sergio Ramos', ..., 7.0, 11.0, '€104.6M'],
#        [11, 182521, 'T. Kroos', ..., 7.0, 10.0, '€156.8M'],
#        ...,
#        [11877, 243155, 'Manu Hernando', ..., 12.0, 5.0, '€1.6M'],
#        [12504, 243315, 'Dani Gómez', ..., 8.0, 14.0, '€2.1M'],
#        [13687, 240311, 'L. Zidane', ..., 62.0, 61.0, '€788K']],
#       dtype=object)

# %%
fifa['Club'].value_counts()
# Out:
# FC Barcelona                 33
# Valencia CF                  33
# Fortuna Düsseldorf           33
# Cardiff City                 33
# Rayo Vallecano               33
#                              ..
# América FC (Minas Gerais)    20
# Fluminense                   20
# Sligo Rovers                 19
# Limerick FC                  19
# Derry City                   18
# Name: Club, Length: 651, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(list(fifa['Club'].value_counts()[0:15]),labels=list(fifa['Club'].value_counts().keys()[0:15]),autopct='%.2f%%')
plt.show()
